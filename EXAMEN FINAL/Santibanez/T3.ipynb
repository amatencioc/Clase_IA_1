# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Absenteeism-data.csv")
df.head(10)
# Out:
#    ID  Reason for Absence        Date  Transportation Expense  \
# 0  11                  26  07/07/2015                     289
# 1  36                   0  14/07/2015                     118
# 2   3                  23  15/07/2015                     179
# 3   7                   7  16/07/2015                     279
# 4  11                  23  23/07/2015                     289
# 5   3                  23  10/07/2015                     179
# 6  10                  22  17/07/2015                     361
# 7  20                  23  24/07/2015                     260
# 8  14                  19  06/07/2015                     155
# 9   1                  22  13/07/2015                     235
#
#    Distance to Work  Age  Daily Work Load Average  Body Mass Index  Education  \
# 0                36   33                  239.554               30          1
# 1                13   50                  239.554               31          1
# ...

# %%
df = df.drop(['ID'], axis = 1)

# %%
df.head(10)
# Out:
#    Reason for Absence        Date  Transportation Expense  Distance to Work  \
# 0                  26  07/07/2015                     289                36
# 1                   0  14/07/2015                     118                13
# 2                  23  15/07/2015                     179                51
# 3                   7  16/07/2015                     279                 5
# 4                  23  23/07/2015                     289                36
# 5                  23  10/07/2015                     179                51
# 6                  22  17/07/2015                     361                52
# 7                  23  24/07/2015                     260                50
# 8                  19  06/07/2015                     155                12
# 9                  22  13/07/2015                     235                11
#
#    Age  Daily Work Load Average  Body Mass Index  Education  Children  Pets  \
# ...

# %%
reason_columns = pd.get_dummies(df['Reason for Absence'])
reason_columns['check'] = reason_columns.sum(axis=1)
reason_columns = reason_columns.drop(['check'], axis = 1)
reason_columns = pd.get_dummies(df['Reason for Absence'], drop_first = True)

# %%
df.head(10)
# Out:
#    Reason for Absence        Date  Transportation Expense  Distance to Work  \
# 0                  26  07/07/2015                     289                36
# 1                   0  14/07/2015                     118                13
# 2                  23  15/07/2015                     179                51
# 3                   7  16/07/2015                     279                 5
# 4                  23  23/07/2015                     289                36
# 5                  23  10/07/2015                     179                51
# 6                  22  17/07/2015                     361                52
# 7                  23  24/07/2015                     260                50
# 8                  19  06/07/2015                     155                12
# 9                  22  13/07/2015                     235                11
#
#    Age  Daily Work Load Average  Body Mass Index  Education  Children  Pets  \
# ...

# %%
reason_type_1 = reason_columns.loc[:, 1:14].max(axis=1)
reason_type_2 = reason_columns.loc[:, 15:17].max(axis=1)
reason_type_3 = reason_columns.loc[:, 18:21].max(axis=1)
reason_type_4 = reason_columns.loc[:, 22:].max(axis=1)
df = pd.concat([df, reason_type_1, reason_type_2, reason_type_3, reason_type_4], axis = 1)
column_names = ['Date', 'Transportation Expense', 'Distance to Work', 'Age',
       'Daily Work Load Average', 'Body Mass Index', 'Education',
       'Children', 'Pets', 'Absenteeism Time in Hours', 'Grupo_1', 'Grupo_2', 'Grupo_3', 'Grupo_4']

df.columns = column_names
df.head(10)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 10
#       5 df = pd.concat([df, reason_type_1, reason_type_2, reason_type_3, reason_type_4], axis = 1)
#       6 column_names = ['Date', 'Transportation Expense', 'Distance to Work', 'Age',
#       7        'Daily Work Load Average', 'Body Mass Index', 'Education',
#       8        'Children', 'Pets', 'Absenteeism Time in Hours', 'Grupo_1', 'Grupo_2', 'Grupo_3', 'Grupo_4']
# ---> 10 df.columns = column_names
#      11 df = df.drop(['Reason for Absence'], axis = 1)
#      12 df.head(10)
#
# File e:\Cibertec\Inteligencia Artificial I\clase18_08\menv\Lib\site-packages\pandas\core\generic.py:6332, in NDFrame.__setattr__(self, name, value)
#    6330 try:
#    6331     object.__getattribute__(self, name)
# -> 6332     return object.__setattr__(self, name, value)
#    6333 except AttributeError:
#    6334     pass
#
# ...

# %%
column_names_reordered = ['Grupo_1', 'Grupo_2', 'Grupo_3', 'Grupo_4',
                          'Date', 'Transportation Expense', 'Distance to Work', 'Age',
       'Daily Work Load Average', 'Body Mass Index', 'Education',
       'Children', 'Pets', 'Absenteeism Time in Hours']

df = df[column_names_reordered]
df.head(10)
# Out:
#    Reason_1  Reason_2  Reason_3  Reason_4        Date  Transportation Expense  \
# 0     False     False     False      True  07/07/2015                     289
# 1     False     False     False     False  14/07/2015                     118
# 2     False     False     False      True  15/07/2015                     179
# 3      True     False     False     False  16/07/2015                     279
# 4     False     False     False      True  23/07/2015                     289
# 5     False     False     False      True  10/07/2015                     179
# 6     False     False     False      True  17/07/2015                     361
# 7     False     False     False      True  24/07/2015                     260
# 8     False     False      True     False  06/07/2015                     155
# 9     False     False     False      True  13/07/2015                     235
#
#    Distance to Work  Age  Daily Work Load Average  Body Mass Index  Education  \
# ...

# %%
df_reason_mod = df.copy()
df_reason_mod['Date'] = pd.to_datetime(df_reason_mod['Date'], format = '%d/%m/%Y')
meses = []
for i in range(df_reason_mod.shape[0]):
    meses.append(df_reason_mod['Date'][i].month)

df_reason_mod['Month Value'] = meses
df.head(10)
# Out:
#    Reason_1  Reason_2  Reason_3  Reason_4        Date  Transportation Expense  \
# 0     False     False     False      True  07/07/2015                     289
# 1     False     False     False     False  14/07/2015                     118
# 2     False     False     False      True  15/07/2015                     179
# 3      True     False     False     False  16/07/2015                     279
# 4     False     False     False      True  23/07/2015                     289
# 5     False     False     False      True  10/07/2015                     179
# 6     False     False     False      True  17/07/2015                     361
# 7     False     False     False      True  24/07/2015                     260
# 8     False     False      True     False  06/07/2015                     155
# 9     False     False     False      True  13/07/2015                     235
#
#    Distance to Work  Age  Daily Work Load Average  Body Mass Index  Education  \
# ...

# %%
df_cleaned = df
df_cleaned.head(10)
# Out:
#    Reason_1  Reason_2  Reason_3  Reason_4        Date  Transportation Expense  \
# 0     False     False     False      True  07/07/2015                     289
# 1     False     False     False     False  14/07/2015                     118
# 2     False     False     False      True  15/07/2015                     179
# 3      True     False     False     False  16/07/2015                     279
# 4     False     False     False      True  23/07/2015                     289
# 5     False     False     False      True  10/07/2015                     179
# 6     False     False     False      True  17/07/2015                     361
# 7     False     False     False      True  24/07/2015                     260
# 8     False     False      True     False  06/07/2015                     155
# 9     False     False     False      True  13/07/2015                     235
#
#    Distance to Work  Age  Daily Work Load Average  Body Mass Index  Education  \
# ...

# %%
def date_to_weekday(date_value):
    return date_value.weekday()

df_reason_mod['Day of the Week'] = df_reason_mod['Date'].apply(date_to_weekday)
df_cleaned.head(10)
# Out:
#    Reason_1  Reason_2  Reason_3  Reason_4        Date  Transportation Expense  \
# 0     False     False     False      True  07/07/2015                     289
# 1     False     False     False     False  14/07/2015                     118
# 2     False     False     False      True  15/07/2015                     179
# 3      True     False     False     False  16/07/2015                     279
# 4     False     False     False      True  23/07/2015                     289
# 5     False     False     False      True  10/07/2015                     179
# 6     False     False     False      True  17/07/2015                     361
# 7     False     False     False      True  24/07/2015                     260
# 8     False     False      True     False  06/07/2015                     155
# 9     False     False     False      True  13/07/2015                     235
#
#    Distance to Work  Age  Daily Work Load Average  Body Mass Index  Education  \
# ...

# %%
df_reason_mod = df_reason_mod.drop(['Date'], axis = 1)
column_names_upd = ['Reason_1', 'Reason_2', 'Reason_3', 'Reason_4', 'Month Value', 'Day of the Week',
       'Transportation Expense', 'Distance to Work', 'Age',
       'Daily Work Load Average', 'Body Mass Index', 'Education', 'Children',
       'Pets', 'Absenteeism Time in Hours']
df_reason_mod = df_reason_mod[column_names_upd]

# %%
df_reason_date_mod = df_reason_mod.copy()

# %%
df_reason_date_mod['Education'] = df_reason_date_mod['Education'].map({1:0, 2:1, 3:1, 4:1})
df_cleaned = df_reason_date_mod.copy()
df_cleaned.head(10)
# Out:
#    Reason_1  Reason_2  Reason_3  Reason_4  Month Value  Day of the Week  \
# 0     False     False     False      True            7                1
# 1     False     False     False     False            7                1
# 2     False     False     False      True            7                2
# 3      True     False     False     False            7                3
# 4     False     False     False      True            7                3
# 5     False     False     False      True            7                4
# 6     False     False     False      True            7                4
# 7     False     False     False      True            7                4
# 8     False     False      True     False            7                0
# 9     False     False     False      True            7                0
#
#    Transportation Expense  Distance to Work  Age  Daily Work Load Average  \
# 0                     289                36   33                  239.554
# ...
