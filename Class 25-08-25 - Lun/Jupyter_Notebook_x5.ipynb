# %%
pip install seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import numpy as np  
print("Setup complete")
# Out:
# Setup complete

# %% [markdown]
# Data visualization with Seaborn
# Cada grafico emplea codigo simple y corto. Hace que sea mas rapido y legible para el uso de otros usuarios
# Excel, entre otros

# %%
#first: complile without index_col & parse_dates
fifa_file=pd.read_csv("fifa.csv",index_col="Date",parse_dates=True)
#parse dates: recognizes the row labels as dates ,

# %%
#Print the first five rows of df
fifa_file.head()
# Out:
#              ARG  BRA   ESP   FRA  GER  ITA
# Date
# 1993-08-08   5.0  8.0  13.0  12.0  1.0  2.0
# 1993-09-23  12.0  1.0  14.0   7.0  5.0  2.0
# 1993-10-22   9.0  1.0   7.0  14.0  4.0  3.0
# 1993-11-19   9.0  4.0   7.0  15.0  3.0  1.0
# 1993-12-23   8.0  3.0   5.0  15.0  1.0  2.0

# %%
#Plot the data:tamaño de la ventana
plt.figure(figsize=(16,6))

#Grafico que muestra como el ranking ha evolucionado durante el tiempo
sns.lineplot(data=fifa_file)
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# Line charts>
# Spotiify music

# %%
spot=pd.read_csv("spotify.csv",index_col="Date",parse_dates=True)

# %%
spot.tail()
# Out:
#             Shape of You  Despacito  Something Just Like This    HUMBLE.  \
# Date
# 2018-01-05       4492978  3450315.0                 2408365.0  2685857.0
# 2018-01-06       4416476  3394284.0                 2188035.0  2559044.0
# 2018-01-07       4009104  3020789.0                 1908129.0  2350985.0
# 2018-01-08       4135505  2755266.0                 2023251.0  2523265.0
# 2018-01-09       4168506  2791601.0                 2058016.0  2727678.0
#
#             Unforgettable
# Date
# 2018-01-05      2869783.0
# 2018-01-06      2743748.0
# 2018-01-07      2441045.0
# 2018-01-08      2622693.0
# 2018-01-09      2627334.0

# %%
plt.figure(figsize=(14,6))
plt.title("Canciones mas sonadas entre 2017 - 2018")
sns.lineplot(data=spot['HUMBLE.'],label="HUMBLE")
# Out:
# <Axes: title={'center': 'Canciones mas sonadas entre 2017 - 2018'}, xlabel='Date', ylabel='HUMBLE.'>

# %% [markdown]
# Does Avila Adobe get more visitors:
#
#     in September-February (in LA, the fall and winter months), or
#     in March-August (in LA, the spring and summer)?
#
# Using this information, when should the museum staff additional seasonal employees?

# %%
musm=pd.read_csv("museum_visitors.csv",index_col="Date",parse_dates=True)
musm.head()
#tipo de string  Date: /-0-9-/
# Out:
#             Avila Adobe  Firehouse Museum  Chinese American Museum  \
# Date
# 2014-01-01        24778              4486                     1581
# 2014-02-01        18976              4172                     1785
# 2014-03-01        25231              7082                     3229
# 2014-04-01        26989              6756                     2129
# 2014-05-01        36883             10858                     3676
#
#             America Tropical Interpretive Center
# Date
# 2014-01-01                                  6602
# 2014-02-01                                  5029
# 2014-03-01                                  8129
# 2014-04-01                                  2824
# 2014-05-01                                 10694

# %%
filtro_primv=  ((musm.index.year!=2014)&(musm.index.month<3)) | ((musm.index.month>=9) & (musm.index.month<=12))
#[9:12]
musm_primv=musm[filtro_primv]
#museum 14-01/02/03 no cntar
sns.lineplot(data=musm_primv)
# Out:
# <Axes: xlabel='Date'>

# %%
musm_primv.head()
# Out:
#             Avila Adobe  Firehouse Museum  Chinese American Museum  \
# Date
# 2014-09-01        28473             61192                     1073
# 2014-10-01        27995              6488                     1979
# 2014-11-01        25691              4189                     2404
# 2014-12-01        18754              4339                     1319
# 2015-01-01        20438              3858                     1823
#
#             America Tropical Interpretive Center
# Date
# 2014-09-01                                  5661
# 2014-10-01                                  7356
# 2014-11-01                                  9773
# 2014-12-01                                  7184
# 2015-01-01                                  6250
